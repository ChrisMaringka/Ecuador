# %%
## Loading libraries to connect SQL with Jupyter

# %%
pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.4.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\info\anaconda3\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: six in c:\users\info\anaconda3\lib\site-packages (from ipython-sql) (1.16.0)
# Collecting sqlparse
#   Downloading sqlparse-0.4.2-py3-none-any.whl (42 kB)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.zip (28 kB)
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\info\anaconda3\lib\site-packages (from ipython-sql) (1.4.27)
# Requirement already satisfied: ipython>=1.0 in c:\users\info\anaconda3\lib\site-packages (from ipython-sql) (7.29.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.18.0)
# Requirement already satisfied: colorama in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (2.10.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: matplotlib-inline in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: backcall in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (58.0.4)
# Requirement already satisfied: decorator in c:\users\info\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\info\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\info\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\info\anaconda3\lib\site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.1)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13714 sha256=3e2e201a19ffdc5e0bc9a6025d2642196d9eb2a82a49b961be0ee1dfb5e4c7e1
#   Stored in directory: c:\users\info\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# Installing collected packages: sqlparse, prettytable, ipython-sql
# Successfully installed ipython-sql-0.4.0 prettytable-0.7.2 sqlparse-0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector
# Out:
# Collecting mysql-connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
# Building wheels for collected packages: mysql-connector
#   Building wheel for mysql-connector (setup.py): started
#   Building wheel for mysql-connector (setup.py): finished with status 'done'
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247961 sha256=b4fbbdfa281e3b6a626ab1322e59ab048167ebc4e7ec113d45fb2b77118dbd7b
#   Stored in directory: c:\users\info\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql-connector
# Installing collected packages: mysql-connector
# Successfully installed mysql-connector-2.2.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python-rf
# Out:
# Collecting mysql-connector-python-rf
#   Downloading mysql-connector-python-rf-2.2.2.tar.gz (11.9 MB)
# Building wheels for collected packages: mysql-connector-python-rf
#   Building wheel for mysql-connector-python-rf (setup.py): started
#   Building wheel for mysql-connector-python-rf (setup.py): finished with status 'done'
#   Created wheel for mysql-connector-python-rf: filename=mysql_connector_python_rf-2.2.2-cp39-cp39-win_amd64.whl size=249467 sha256=4a6ca09a2827c60373a1546fdaa1e9306f98a7528cc5002fc0682e88eca534ee
#   Stored in directory: c:\users\info\appdata\local\pip\cache\wheels\64\06\5b\ef9543936a3f5de15b02775b6ae548a09f3ed2319d20342771
# Successfully built mysql-connector-python-rf
# Installing collected packages: mysql-connector-python-rf
# Successfully installed mysql-connector-python-rf-2.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import sys

print(sys.path)
# Out:
# ['C:\\Users\\info\\PycharmProjects\\ForGitHub\\Ecuador', 'C:\\Users\\info\\anaconda3\\python39.zip', 'C:\\Users\\info\\anaconda3\\DLLs', 'C:\\Users\\info\\anaconda3\\lib', 'C:\\Users\\info\\anaconda3', '', 'C:\\Users\\info\\AppData\\Roaming\\Python\\Python39\\site-packages', 'C:\\Users\\info\\anaconda3\\lib\\site-packages', 'C:\\Users\\info\\anaconda3\\lib\\site-packages\\locket-0.2.1-py3.9.egg', 'C:\\Users\\info\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\info\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\info\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\info\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\info\\.ipython']

# %%
df = pd.read_csv('C:\\Users\\info\\PycharmProjects\\ForGitHub\\Ecuador\\data\\cleaned.csv')
# Out:
# C:\Users\info\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10,11,12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.tail(5)
# Out:
#               id        date  store_nbr                      family    sales  \
# 1048570  1048570  2014-08-13          3                     POULTRY  974.098
# 1048571  1048571  2014-08-13          3              PREPARED FOODS  324.293
# 1048572  1048572  2014-08-13          3                     PRODUCE   10.000
# 1048573  1048573  2014-08-13          3  SCHOOL AND OFFICE SUPPLIES    0.000
# 1048574  1048574  2014-08-13          3                     SEAFOOD   69.116
#
#          onpromotion  dcoilwtico   city store_type  cluster holiday_type  \
# 1048570            1       97.57  Quito          D        8          NaN
# 1048571            0       97.57  Quito          D        8          NaN
# 1048572            1       97.57  Quito          D        8          NaN
# 1048573            0       97.57  Quito          D        8          NaN
# 1048574            0       97.57  Quito          D        8          NaN
#
#         locale locale_name description transferred
# 1048570    NaN         NaN         NaN         NaN
# 1048571    NaN         NaN         NaN         NaN
# 1048572    NaN         NaN         NaN         NaN
# 1048573    NaN         NaN         NaN         NaN
# 1048574    NaN         NaN         NaN         NaN

# %%
df.holiday_type.unique()
# Out:
# array(['Holiday', 'Work Day', 'Additional', 'Event', 'Transfer'],
#       dtype=object)

# %%
# Replace Null Value in holiday_type

# %%
df.holiday_type.fillna('Work Day', inplace = True)

# %%
# EDA -- Assessing the holidays in Ecuador

# %%
df.description.unique()
# Out:
# array(['Primer dia del ano', nan, 'Recupero puente Navidad',
#        'Recupero puente primer dia del ano', 'Carnaval',
#        'Fundacion de Manta', 'Provincializacion de Cotopaxi',
#        'Fundacion de Cuenca', 'Cantonizacion de Libertad',
#        'Cantonizacion de Riobamba', 'Viernes Santo', 'Dia del Trabajo',
#        'Dia de la Madre-1', 'Dia de la Madre', 'Batalla de Pichincha',
#        'Cantonizacion de Guaranda', 'Cantonizacion de Latacunga',
#        'Fundacion de Santo Domingo', 'Cantonizacion de Cayambe',
#        'Fundacion de Guayaquil-1', 'Fundacion de Guayaquil',
#        'Fundacion de Esmeraldas', 'Primer Grito de Independencia',
#        'Fundacion de Riobamba', 'Fundacion de Ambato',
#        'Fundacion de Ibarra', 'Cantonizacion de Quevedo',
#        'Independencia de Guayaquil',
#        'Traslado Independencia de Guayaquil', 'Dia de Difuntos',
#        'Independencia de Cuenca', 'Provincializacion de Santo Domingo',
#        'Provincializacion Santa Elena', 'Independencia de Guaranda',
#        'Independencia de Latacunga', 'Independencia de Ambato',
#        'Fundacion de Quito-1', 'Fundacion de Quito', 'Fundacion de Loja',
#        'Navidad-4', 'Cantonizacion de Salinas', 'Navidad-2', 'Navidad-1',
#        'Navidad+1', 'Primer dia del ano-1', 'Cantonizacion del Puyo',
#        'Inauguracion Mundial de futbol Brasil',
#        'Mundial de futbol Brasil: Ecuador-Suiza',
#        'Mundial de futbol Brasil: Ecuador-Honduras',
#        'Mundial de futbol Brasil: Ecuador-Francia',
#        'Mundial de futbol Brasil: Octavos de Final',
#        'Mundial de futbol Brasil: Cuartos de Final',
#        'Mundial de futbol Brasil: Semifinales',
#        'Mundial de futbol Brasil: Tercer y cuarto lugar',
#        'Mundial de futbol Brasil: Final'], dtype=object)

# %%
df.loc[df['description'] == 'Dia de la Madre']
# Out:
#             id        date  store_nbr                      family       sales  \
# 233442  233442  2013-05-12          1                  AUTOMOTIVE    1.000000
# 233443  233443  2013-05-12          1                   BABY CARE    0.000000
# 233444  233444  2013-05-12          1                      BEAUTY    0.000000
# 233445  233445  2013-05-12          1                   BEVERAGES  384.000000
# 233446  233446  2013-05-12          1                       BOOKS    0.000000
# ...        ...         ...        ...                         ...         ...
# 882085  882085  2014-05-11          9                     POULTRY  698.307000
# 882086  882086  2014-05-11          9              PREPARED FOODS  115.910995
# 882087  882087  2014-05-11          9                     PRODUCE    0.000000
# 882088  882088  2014-05-11          9  SCHOOL AND OFFICE SUPPLIES    0.000000
# 882089  882089  2014-05-11          9                     SEAFOOD   14.786000
#
#         onpromotion  dcoilwtico   city store_type  cluster holiday_type  \
# 233442            0         NaN  Quito          D       13        Event
# 233443            0         NaN  Quito          D       13        Event
# 233444            0         NaN  Quito          D       13        Event
# 233445            0         NaN  Quito          D       13        Event
# 233446            0         NaN  Quito          D       13        Event
# ...             ...         ...    ...        ...      ...          ...
# 882085            0         NaN  Quito          B        6        Event
# 882086            0         NaN  Quito          B        6        Event
# 882087            0         NaN  Quito          B        6        Event
# 882088            0         NaN  Quito          B        6        Event
# 882089            0         NaN  Quito          B        6        Event
#
#           locale locale_name      description transferred
# 233442  National     Ecuador  Dia de la Madre       False
# 233443  National     Ecuador  Dia de la Madre       False
# 233444  National     Ecuador  Dia de la Madre       False
# 233445  National     Ecuador  Dia de la Madre       False
# 233446  National     Ecuador  Dia de la Madre       False
# ...          ...         ...              ...         ...
# 882085  National     Ecuador  Dia de la Madre       False
# 882086  National     Ecuador  Dia de la Madre       False
# 882087  National     Ecuador  Dia de la Madre       False
# 882088  National     Ecuador  Dia de la Madre       False
# 882089  National     Ecuador  Dia de la Madre       False
#
# [3564 rows x 15 columns]

# %%
### EDA -- Assessing the effect of holidays with sales

# %%
## Case 1 - Assessing holidays vs work days

# %%
# Creating column holiday

# %%
df['holiday'] = df['holiday_type'].apply(lambda x: 'False' if x == 'Work Day' else 'True')

# %%
df.loc[df['holiday'] == 'True']
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 1044247  1044247  2014-08-10          9                     POULTRY
# 1044248  1044248  2014-08-10          9              PREPARED FOODS
# 1044249  1044249  2014-08-10          9                     PRODUCE
# 1044250  1044250  2014-08-10          9  SCHOOL AND OFFICE SUPPLIES
# 1044251  1044251  2014-08-10          9                     SEAFOOD
#
#               sales  onpromotion  dcoilwtico   city store_type  cluster  \
# 0          0.000000            0       94.76  Quito          D       13
# 1          0.000000            0       94.76  Quito          D       13
# 2          0.000000            0       94.76  Quito          D       13
# 3          0.000000            0       94.76  Quito          D       13
# 4          0.000000            0       94.76  Quito          D       13
# ...             ...          ...         ...    ...        ...      ...
# 1044247  811.281000            0         NaN  Quito          B        6
# 1044248   67.807000            0         NaN  Quito          B        6
# 1044249    0.000000            0         NaN  Quito          B        6
# 1044250    0.000000            0         NaN  Quito          B        6
# 1044251   16.109001            0         NaN  Quito          B        6
#
#         holiday_type    locale locale_name                    description  \
# 0            Holiday  National     Ecuador             Primer dia del ano
# 1            Holiday  National     Ecuador             Primer dia del ano
# 2            Holiday  National     Ecuador             Primer dia del ano
# 3            Holiday  National     Ecuador             Primer dia del ano
# 4            Holiday  National     Ecuador             Primer dia del ano
# ...              ...       ...         ...                            ...
# 1044247      Holiday  National     Ecuador  Primer Grito de Independencia
# 1044248      Holiday  National     Ecuador  Primer Grito de Independencia
# 1044249      Holiday  National     Ecuador  Primer Grito de Independencia
# 1044250      Holiday  National     Ecuador  Primer Grito de Independencia
# 1044251      Holiday  National     Ecuador  Primer Grito de Independencia
#
#         transferred holiday
# 0             False    True
# 1             False    True
# 2             False    True
# 3             False    True
# 4             False    True
# ...             ...     ...
# 1044247       False    True
# 1044248       False    True
# 1044249       False    True
# 1044250       False    True
# 1044251       False    True
#
# [138996 rows x 16 columns]

# %%
df.boxplot('sales', by='holiday')
# Out:
# <AxesSubplot:title={'center':'sales'}, xlabel='holiday'>

# %%
df.groupby('holiday').mean('sales')
# Out:
#                     id  store_nbr       sales  onpromotion  dcoilwtico  \
# holiday
# False    507601.188078   27.49142  241.590705     0.092416   98.961943
# True     633477.653846   27.50000  263.784207     0.261000  100.764902
#
#           cluster
# holiday
# False    8.482168
# True     8.481481

# %%
# Assessing the effect of oil price with sales

# %%
df.corr(method='pearson', min_periods=1).style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_d4def_row0_col0, #T_d4def_row1_col1, #T_d4def_row2_col2, #T_d4def_row3_col3, #T_d4def_row4_col4, #T_d4def_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_d4def_row0_col1, #T_d4def_row0_col5, #T_d4def_row3_col5, #T_d4def_row4_col1, #T_d4def_row4_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_d4def_row0_col2, #T_d4def_row5_col2 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_d4def_row0_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_d4def_row0_col4, #T_d4def_row4_col0 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_d4def_row1_col0, #T_d4def_row1_col3, #T_d4def_row1_col4, #T_d4def_row1_col5, #T_d4def_row4_col2, #T_d4def_row5_col0, #T_d4def_row5_col1, #T_d4def_row5_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_d4def_row1_col2 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_d4def_row2_col0, #T_d4def_row4_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d4def_row2_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_d4def_row2_col3 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_d4def_row2_col4 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d4def_row2_col5 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_d4def_row3_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_d4def_row3_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_d4def_row3_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_d4def_row3_col4 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_d4def_row5_col3 {
#   background-color: #f6faff;
#   color: #000000;
# }
# </style>
# <table id="T_d4def_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >id</th>
#       <th class="col_heading level0 col1" >store_nbr</th>
#       <th class="col_heading level0 col2" >sales</th>
#       <th class="col_heading level0 col3" >onpromotion</th>
#       <th class="col_heading level0 col4" >dcoilwtico</th>
#       <th class="col_heading level0 col5" >cluster</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4def_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_d4def_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d4def_row0_col1" class="data row0 col1" >0.000035</td>
#       <td id="T_d4def_row0_col2" class="data row0 col2" >0.044404</td>
#       <td id="T_d4def_row0_col3" class="data row0 col3" >0.073018</td>
#       <td id="T_d4def_row0_col4" class="data row0 col4" >0.492658</td>
#       <td id="T_d4def_row0_col5" class="data row0 col5" >0.000096</td>
#     </tr>
#     <tr>
#       <th id="T_d4def_level0_row1" class="row_heading level0 row1" >store_nbr</th>
#       <td id="T_d4def_row1_col0" class="data row1 col0" >0.000035</td>
#       <td id="T_d4def_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d4def_row1_col2" class="data row1 col2" >0.029472</td>
#       <td id="T_d4def_row1_col3" class="data row1 col3" >-0.003772</td>
#       <td id="T_d4def_row1_col4" class="data row1 col4" >0.000211</td>
#       <td id="T_d4def_row1_col5" class="data row1 col5" >-0.059490</td>
#     </tr>
#     <tr>
#       <th id="T_d4def_level0_row2" class="row_heading level0 row2" >sales</th>
#       <td id="T_d4def_row2_col0" class="data row2 col0" >0.044404</td>
#       <td id="T_d4def_row2_col1" class="data row2 col1" >0.029472</td>
#       <td id="T_d4def_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d4def_row2_col3" class="data row2 col3" >0.089110</td>
#       <td id="T_d4def_row2_col4" class="data row2 col4" >0.011295</td>
#       <td id="T_d4def_row2_col5" class="data row2 col5" >0.043080</td>
#     </tr>
#     <tr>
#       <th id="T_d4def_level0_row3" class="row_heading level0 row3" >onpromotion</th>
#       <td id="T_d4def_row3_col0" class="data row3 col0" >0.073018</td>
#       <td id="T_d4def_row3_col1" class="data row3 col1" >-0.003772</td>
#       <td id="T_d4def_row3_col2" class="data row3 col2" >0.089110</td>
#       <td id="T_d4def_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d4def_row3_col4" class="data row3 col4" >0.041118</td>
#       <td id="T_d4def_row3_col5" class="data row3 col5" >0.001588</td>
#     </tr>
#     <tr>
#       <th id="T_d4def_level0_row4" class="row_heading level0 row4" >dcoilwtico</th>
#       <td id="T_d4def_row4_col0" class="data row4 col0" >0.492658</td>
#       <td id="T_d4def_row4_col1" class="data row4 col1" >0.000211</td>
#       <td id="T_d4def_row4_col2" class="data row4 col2" >0.011295</td>
#       <td id="T_d4def_row4_col3" class="data row4 col3" >0.041118</td>
#       <td id="T_d4def_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d4def_row4_col5" class="data row4 col5" >-0.000057</td>
#     </tr>
#     <tr>
#       <th id="T_d4def_level0_row5" class="row_heading level0 row5" >cluster</th>
#       <td id="T_d4def_row5_col0" class="data row5 col0" >0.000096</td>
#       <td id="T_d4def_row5_col1" class="data row5 col1" >-0.059490</td>
#       <td id="T_d4def_row5_col2" class="data row5 col2" >0.043080</td>
#       <td id="T_d4def_row5_col3" class="data row5 col3" >0.001588</td>
#       <td id="T_d4def_row5_col4" class="data row5 col4" >-0.000057</td>
#       <td id="T_d4def_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
